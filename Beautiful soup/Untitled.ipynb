# %%
import requests 
from bs4 import BeautifulSoup

# %%
url='https://www.linkedin.com/jobs/collections/?currentJobId=3378645795'

# %%
a=requests.get(url)

# %%
soup=BeautifulSoup(a.content,"html.parser")
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n <head>\n  <meta content="d_registration-cold-join" name="pageKey"/>\n  <meta content="en_US" name="locale"/>\n  <meta data-app-id="com.linkedin.registration-frontend.d_web" data-app-version="" data-custom-tracking-code="" data-disable-comscore-tracking="" data-enable-page-view-heartbeat-tracking="" data-jet-tags="" data-multiproduct-name="registration-fe" data-service-name="registration-frontend" data-tracking-page-type="" id="config">\n   <link href="https://www.linkedin.com/signup" rel="canonical"/>\n   <link href="https://static-exp1.licdn.com/sc/h/al2o9zrvru7aqj8e1x2rzsrca" rel="icon"/>\n   <script>\n    function getDfd() {let yFn,nFn;const p=new Promise((y, n)=>{yFn=y;nFn=n;});p.resolve=yFn;p.reject=nFn;return p;}window.lazyloader = getDfd();window.tracking = getDfd();window.impressionTracking = getDfd();window.pemTracking = getDfd();window.ingraphTracking = getDfd();window.appDetection = getDfd();\n   </script>\n   <title>\n    Sign Up | LinkedIn\n   </title>\n   <meta content="500 million+ members | Manage your professional identity. Build and engage with your professional network. Access knowledge, insights and opportunities." name="description"/>\n   <meta content="Sign Up | LinkedIn" property="og:title">\n    <meta content="500 million+ members | Manage your professional identity. Build and engage with your professional network. Access knowledge, insights and opportunities." property="og:description">\n     <meta content="https://static-exp1.licdn.com/scds/common/u/images/logos/favicons/v1/favicon.ico" property="og:image"/>\n     <meta content="article" property="og:type"/>\n     <meta content="https://www.linkedin.com/signup" property="og:url"/>\n     <meta content="summary" name="twitter:card"/>\n     <meta content="@linkedin" name="twitter:site"/>\n     <meta content="Sign Up | LinkedIn" name="twitter:title"/>\n     <meta content="500 million+ members | Manage your professional identity. Build and engage with your professional network. Access knowledge, insights and opportunities." name="twitter:description"/>\n     <meta content="https://static-exp1.licdn.com/scds/common/u/images/logos/favicons/v1/favicon.ico" name="twitter:image"/>\n     <meta content="noarchive" name="robots"/>\n     <meta content="https://static-exp1.licdn.com/sc/h/6sz1e821vgereyxaakx87tt4z" id="artdeco/static/images/icons.svg" name="asset-url"/>\n     <meta content="registration-frontend" name="litmsProfileName"/>\n     <style>\n      /* this prevents animations from running when the page is initially loaded */.page--isLoading * {transition: none !important;}\n     </style>\n     <link href="https://static-exp1.licdn.com/sc/h/9x0g1joddcw7oh2qqggtp9nca" rel="stylesheet">\n      <link href="https://static-exp1.licdn.com/sc/h/n29z00oqpkharvnrwsjpo0jd" rel="stylesheet">\n       <link href="https://static-exp1.licdn.com/sc/h/3gnk30l4rk7evi8ph6nrpjo5v" rel="stylesheet"/>\n       <link href="https://static-exp1.licdn.com/sc/h/2p8homyoyx09qq6hsy1b1c61n" rel="stylesheet"/>\n      </link>\n     </link>\n    </meta>\n   </meta>\n  </meta>\n </head>\n <body>\n  <div class="page page--isLoading page--is-mercado-theme-enabled">\n   <main class="main">\n    <code id="registrationUrl" style="display: none;">\n     <!--"/signup/api/cors/createAccount?trk=login_reg_redirect"-->\n    </code>\n    <code id="dust-var-mwebMercadoMod" style="display: none;">\n     <!--false-->\n    </code>\n    <code id="i18n_continue" style="display: none;">\n     <!--"Continue"-->\n    </code>\n    <code id="dust-var-isSplitJoinForm" style="display: none;">\n     <!--"true"-->\n    </code>\n    <code id="dust-var-isSmartLockEnabled" style="display: none;">\n     <!--"true"-->\n    </code>\n    <code id="dust-var-joinBtnProvider" style="display: none;">\n     <!--"GOOGLE"-->\n    </code>\n    <code id="dust-var-isMobile" style="display: none;">\n     <!--false-->\n    </code>\n    <code id="dust-var-invitationId" style="display: none;">\n     < ...

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en"><head><meta content="d_registration-cold-join" name="pageKey"/><meta content="en_US" name="locale"/><meta data-app-id="com.linkedin.registration-frontend.d_web" data-app-version="" data-custom-tracking-code="" data-disable-comscore-tracking="" data-enable-page-view-heartbeat-tracking="" data-jet-tags="" data-multiproduct-name="registration-fe" data-service-name="registration-frontend" data-tracking-page-type="" id="config"/><link href="https://www.linkedin.com/signup" rel="canonical"/><link href="https://static-exp1.licdn.com/sc/h/al2o9zrvru7aqj8e1x2rzsrca" rel="icon"/><script>function getDfd() {let yFn,nFn;const p=new Promise((y, n)=>{yFn=y;nFn=n;});p.resolve=yFn;p.reject=nFn;return p;}window.lazyloader = getDfd();window.tracking = getDfd();window.impressionTracking = getDfd();window.pemTracking = getDfd();window.ingraphTracking = getDfd();window.appDetection = getDfd();</script><title>Sign Up | LinkedIn</title><meta content="500 million+ members | Manage your professional identity. Build and engage with your professional network. Access knowledge, insights and opportunities." name="description"/><meta content="Sign Up | LinkedIn" property="og:title"/><meta content="500 million+ members | Manage your professional identity. Build and engage with your professional network. Access knowledge, insights and opportunities." property="og:description"/><meta content="https://static-exp1.licdn.com/scds/common/u/images/logos/favicons/v1/favicon.ico" property="og:image"/><meta content="article" property="og:type"/><meta content="https://www.linkedin.com/signup" property="og:url"/><meta content="summary" name="twitter:card"/><meta content="@linkedin" name="twitter:site"/><meta content="Sign Up | LinkedIn" name="twitter:title"/><meta content="500 million+ members | Manage your professional identity. Build and engage with your professional network. Access knowledge, insights and opportunities." name="twitter:description"/><meta content="https://static-exp1.licdn.com/scds/common/u/images/logos/favicons/v1/favicon.ico" name="twitter:image"/><meta content="noarchive" name="robots"/><meta content="https://static-exp1.licdn.com/sc/h/6sz1e821vgereyxaakx87tt4z" id="artdeco/static/images/icons.svg" name="asset-url"/><meta content="registration-frontend" name="litmsProfileName"/><style>/* this prevents animations from running when the page is initially loaded */.page--isLoading * {transition: none !important;}</style><link href="https://static-exp1.licdn.com/sc/h/9x0g1joddcw7oh2qqggtp9nca" rel="stylesheet"/>
# <link href="https://static-exp1.licdn.com/sc/h/n29z00oqpkharvnrwsjpo0jd" rel="stylesheet"/>
# <link href="https://static-exp1.licdn.com/sc/h/3gnk30l4rk7evi8ph6nrpjo5v" rel="stylesheet"/>
# <link href="https://static-exp1.licdn.com/sc/h/2p8homyoyx09qq6hsy1b1c61n" rel="stylesheet"/>
# </head><body><div class="page page--isLoading page--is-mercado-theme-enabled"><main class="main"><code id="registrationUrl" style="display: none;"><!--"/signup/api/cors/createAccount?trk=login_reg_redirect"--></code><code id="dust-var-mwebMercadoMod" style="display: none;"><!--false--></code><code id="i18n_continue" style="display: none;"><!--"Continue"--></code><code id="dust-var-isSplitJoinForm" style="display: none;"><!--"true"--></code><code id="dust-var-isSmartLockEnabled" style="display: none;"><!--"true"--></code><code id="dust-var-joinBtnProvider" style="display: none;"><!--"GOOGLE"--></code><code id="dust-var-isMobile" style="display: none;"><!--false--></code><code id="dust-var-invitationId" style="display: none;"><!--false--></code><code id="dust-var-sharedKey" style="display: none;"><!--false--></code><code id="dust-var-cancelOnboardingRedirect" style="display: none;"><!--false--></code><code id="dust-var-postOnboardingRedirectUrl" style="display: none;"><!--"https://www.linkedin.com/jobs/collections/?currentJobId=3378645795"--></code><code id="dust-var-source" style="display: none;"><!--false--></code><code id="dust-var-fpLixTreatment" style="display: none;"><!--"enabled"--></code><code id="dust-var-pemDegradationTrackingTreatment" style="display: none;"><!--"enabled"--></code><code id="dust-var-sendConfirmationEmail" style="display: none;"><!--"true"--></code><code id="dust-var-isInlineError" style="display: none;"><!--"true"--></code><code id="dust-var-isInstantThirdPartyBtnEnabled" style="display: none;"><!--"true"--></code><code id="dust-var-apfcDf" style="display: none;"><!--"enabled"--></code><code id="dust-var-hasShowPassword" style="display: none;"><!--"true"--></code><code id="dust-var-hasMultipleSocialJoin" style="display: none;"><!--false--></code><code id="dust-var-useGoogleGSI" style="display: none;"><!--"true"--></code><code id="dust-var-loginCsrfParam" style="display: none;"><!--"68f57a48-4f67-405f-826d-f9cb2b07d06c"--></code><code id="dust-var-shouldSignInOnDuplicateAccount" style="display: none;"><!--false--></code><code id="dust-var-signInOnDuplicateAccountUrl" style="display: none;"><!--"/checkpoint/lg/login-submit"--></code><code id="i18n_hide_password_aria_label" style="display: none;"><!--"Hide your LinkedIn password"--></code><code id="i18n_show_password_aria_label" style="display: none;"><!--"Show your LinkedIn password"--></code><form class="join-form"><header class="main__header"><div class="main__logo-container" tabindex="0"><span aria-label="LinkedIn logo"><icon a11y-text="LinkedIn logo" class="main__logo" data-delayed-url="https://static-exp1.licdn.com/sc/h/ci0l2cumjj4m4gmazvviqvp47"></icon></span></div><h1 class="main__subtitle main__subtitle--is-cold-join main__subtitle--mod-A">Make the most of your professional life</h1></header><div class="profile-card hidden"><div class="profile-card__content"><img alt="profile photo" class="profile-card__photo"/><li-icon aria-hidden="true" class="profile-card__edit-icon" size="small" title="edit" type="pencil-icon"></li-icon><div class="profile-card__info"><h3 class="profile-card__info-name"></h3><h3 class="profile-card__info-email"></h3></div><span class="profile-card__not-you">Not you?</span></div></div><div class="profile-card__edit-photo-modal hidden"><div class="profile-card__edit-photo-content"><div class="profile-card__edit-photo-cancel"><li-icon aria-hidden="true" class="profile-card__edit-photo-cancel-icon" size="small" title="edit" type="cancel-icon"></li-icon></div><div class="profile-card__edit-photo-remove"><p class="profile-card__edit-photo-text">Remove Photo</p></div></div></div><section class="join-form__form-body join-form__form-body--gsi"><div class="join-form__form-input-container join-form__form-input-container--is-last-section join-form__form-input-container--is-hidden"><label class="input__label" for="first-name">First name</label><input autocomplete="on" class="input__input" id="first-name" name="first-name" placeholder="Fi ...

# %%
soup.code
# Out:
# <code id="registrationUrl" style="display: none;"><!--"/signup/api/cors/createAccount?trk=login_reg_redirect"--></code>

# %%
soup.find
